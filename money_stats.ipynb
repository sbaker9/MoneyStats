# %%
import pandas as pd

# %%
dataframes = pd.read_html('./data/html.html', header=0, index_col=0, skiprows=0)
df = dataframes[0]

# drop rows with all values NaN (Not A Number)
df = df.dropna(how='all')

# print(df.columns.values)
# get desired column names
header_names = df.columns.values[0:5]
print(header_names)

# the dollar amounts are in columns "Unnamed:25 through Unnamed:28
# slice columns with dollar amounts
# df = df.loc[:, "Trend":"Unnamed: 24"]
df = df.loc[:, "Unnamed: 25": 'Unnamed: 28']

df
# Out:
# ['Trend' '12/31/2018' '12/31/2017' '12/31/2016' '12/31/2015']
#                                                 Unnamed: 25  Unnamed: 26  \
# Period Ending:
# Total Revenue                                   $15,794,341  $11,692,713
# Cost of Revenue                                  $9,967,538   $8,033,000
# Gross Profit                                     $5,826,803   $3,659,713
# Research and Development                         $1,221,814     $953,710
# Sales, General and Admin.                        $2,999,763   $1,867,324
# Non-Recurring Items                                     NaN          NaN
# Other Operating Items                                   NaN          NaN
# Operating Income                                 $1,605,226     $838,679
# Add'l income/expense items                              NaN          NaN
# Earnings Before Interest and Tax                 $1,646,951     $723,525
# Interest Expense                                   $420,493     $238,204
# Earnings Before Tax                              $1,226,458     $485,321
# Income Tax                                          $15,216    ($73,608)
# Minority Interest                                       NaN          NaN
# Equity Earnings/Loss Unconsolidated Subsidiary          NaN          NaN
# Net Income-Cont. Operations                      $1,211,242     $558,929
# Net Income                                       $1,211,242     $558,929
# Net Income Applicable to Common Shareholders     $1,211,242     $558,929
#
#                                                Unnamed: 27 Unnamed: 28
# Period Ending:
# Total Revenue                                   $8,830,669  $6,779,511
# Cost of Revenue                                 $6,257,462  $4,591,476
# Gross Profit                                    $2,573,207  $2,188,035
# Research and Development                          $780,232    $650,788
# Sales, General and Admin.                       $1,413,182  $1,231,421
# Non-Recurring Items                                    NaN         NaN
# Other Operating Items                                  NaN         NaN
# Operating Income                                  $379,793    $305,826
# Add'l income/expense items                         $41,725  ($115,154)
# Earnings Before Interest and Tax                  $410,621    $274,601
# Interest Expense                                  $150,114    $132,716
# Earnings Before Tax                               $260,507    $141,885
# Income Tax                                         $73,829     $19,244
# Minority Interest                                      NaN         NaN
# Equity Earnings/Loss Unconsolidated Subsidiary         NaN         NaN
# Net Income-Cont. Operations                       $186,678    $122,641
# Net Income                                        $186,678    $122,641
# Net Income Applicable to Common Shareholders      $186,678    $122,641
