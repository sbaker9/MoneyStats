# %%
import pandas as pd
import filename_constructor
import scrapper

# %%
filename = filename_constructor.get_income_csv_filename('nflx')
income_df = scrapper.get_dataframe_from_csv_file(filename)
income_df
# Out:
#                                                  12/31/2018   12/31/2017  \
# Period Ending:
# Total Revenue                                   $15,794,341  $11,692,713
# Cost of Revenue                                  $9,967,538   $8,033,000
# Gross Profit                                     $5,826,803   $3,659,713
# Research and Development                         $1,221,814     $953,710
# Sales, General and Admin.                        $2,999,763   $1,867,324
# Non-Recurring Items                                     NaN          NaN
# Other Operating Items                                   NaN          NaN
# Operating Income                                 $1,605,226     $838,679
# Add'l income/expense items                              NaN          NaN
# Earnings Before Interest and Tax                 $1,646,951     $723,525
# Interest Expense                                   $420,493     $238,204
# Earnings Before Tax                              $1,226,458     $485,321
# ...

# %%
revenue = scrapper.get_revenue(income_df)
print(revenue)
"""
12/31/2018    15794341.0
12/31/2017    11692713.0
12/31/2016     8830669.0
12/31/2015     6779511.0
Name: Total Revenue, dtype: float64
"""
# Out:
# 12/31/2018    15794341.0
# 12/31/2017    11692713.0
# 12/31/2016     8830669.0
# 12/31/2015     6779511.0
# Name: Total Revenue, dtype: float64

# %%
filename = filename_constructor.get_balance_sheet_csv_filename('nflx')
balance_sheet_df = scrapper.get_dataframe_from_csv_file(filename)
balance_sheet_df
# Out:
#                                                      12/31/2018   12/31/2017  \
# Period Ending:
# Cash and Cash Equivalents                            $3,794,483   $2,822,795
# Short-Term Investments                                      NaN          NaN
# Net Receivables                                             NaN          NaN
# Inventory                                                   NaN          NaN
# Other Current Assets                                 $5,899,652   $4,847,179
# Total Current Assets                                 $9,694,135   $7,669,974
# Long-Term Investments                                       NaN          NaN
# Fixed Assets                                           $418,281     $319,404
# Goodwill                                                    NaN          NaN
# Intangible Assets                                   $14,960,954  $10,371,055
# Other Assets                                           $901,030     $652,309
# ...

# %%
equity = scrapper.get_equity(balance_sheet_df)
print(equity)
"""
12/31/2018    5238765.0
12/31/2017    3581956.0
12/31/2016    2679800.0
12/31/2015    2223426.0
Name: Total Equity, dtype: float64
"""
# Out:
# 12/31/2018    5238765.0
# 12/31/2017    3581956.0
# 12/31/2016    2679800.0
# 12/31/2015    2223426.0
# Name: Total Equity, dtype: float64
